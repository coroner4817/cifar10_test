# %%
from aug_algo import aug_algo
import cv2
from IPython.display import Image

# %%
aug = aug_algo()

p = cv2.imread('./data/train/c0/img_8954.jpg')

p = aug.rotatedCW(p, 0.1, 0.25, 1.2)


cv2.imwrite('test.jpg', p)
Image('./test.jpg')

# %%
import numpy as np

p = np.array([1, 3, 2, 7, 12, 2])

idx = np.where(p==2)
print idx[0][0]
# Out:
# 2

# %%
a=np.array([[1, 3, 4, 5], [1, 3, 4, 5]])
print np.ravel(a)
# Out:
# [1 3 4 5 1 3 4 5]
